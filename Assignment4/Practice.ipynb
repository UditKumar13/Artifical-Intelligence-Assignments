# %%
import numpy as np 
import pandas as pd

# %%
job_Roledata = pd.read_csv("roo_data.csv")

# %%
job_Roledata
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                            69                        63
# 1                                            78                        62
# 2                                            71                        86
# 3                                            76                        87
# 4                                            92                        62
# ...                                         ...                       ...
# 19995                                        83                        67
# 19996                                        80                        69
# 19997                                        83                        70
# 19998                                        68                        87
# 19999                                        73                        77
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# ...

# %%
object_Columns = job_Roledata.select_dtypes(include=['object']).copy()

# %%
print("dhape of only object data",object_Columns.shape)
# Out:
# dhape of only object data (20000, 25)

# %%
object_Columns.drop(['Suggested Job Role'], axis = 1, inplace = True)

# %%
print("dhape of only object data",object_Columns.shape)
# Out:
# dhape of only object data (20000, 24)

# %%
from sklearn.preprocessing import OneHotEncoder
le = OneHotEncoder()
object_Columns= le.fit_transform(object_Columns)

# %%
print(object_Columns)
# Out:
#   (0, 1)	1.0
#   (0, 3)	1.0
#   (0, 5)	1.0
#   (0, 14)	1.0
#   (0, 15)	1.0
#   (0, 23)	1.0
#   (0, 26)	1.0
#   (0, 27)	1.0
#   (0, 30)	1.0
#   (0, 37)	1.0
#   (0, 47)	1.0
#   (0, 49)	1.0
#   (0, 59)	1.0
#   (0, 61)	1.0
#   (0, 63)	1.0
#   (0, 86)	1.0
#   (0, 97)	1.0
#   (0, 98)	1.0
#   (0, 101)	1.0
#   (0, 102)	1.0
#   (0, 104)	1.0
#   (0, 106)	1.0
#   (0, 109)	1.0
#   (0, 110)	1.0
#   (1, 1)	1.0
#   :	:
#   (19998, 110)	1.0
#   (19999, 1)	1.0
#   (19999, 3)	1.0
#   (19999, 5)	1.0
#   (19999, 6)	1.0
#   (19999, 17)	1.0
#   (19999, 23)	1.0
#   (19999, 26)	1.0
#   (19999, 27)	1.0
#   (19999, 30)	1.0
#   (19999, 34)	1.0
#   (19999, 48)	1.0
#   (19999, 50)	1.0
#   (19999, 53)	1.0
#   (19999, 62)	1.0
#   (19999, 63)	1.0
#   (19999, 71)	1.0
#   (19999, 96)	1.0
#   (19999, 98)	1.0
#   (19999, 100)	1.0
#   (19999, 102)	1.0
#   (19999, 105)	1.0
#   (19999, 106)	1.0
#   (19999, 109)	1.0
#   (19999, 110)	1.0

# %%
uk_Classifier = models.Sequential()
#Input layer 
uk_Classifier.add(Dense(units = 50, activation = 'relu',input_shape=(38, )))
#hideen layer
uk_Classifier.Dropout(0.3, noise_shape=None, seed=None)
uk_Classifier.add(Dense(units = 3, activation = 'relu'))
uk_Classifier.add(Dense(units = 1, activation = 'softmax'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\UDITKU~1\AppData\Local\Temp/ipykernel_12188/3706618119.py in <module>
# ----> 1 object_Columns.iloc[:,3]= le.fit_transform(object_Columns.iloc[:,3])
#
# c:\users\udit kumar\appdata\local\programs\python\python39\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     685             return self.getnnz()
#     686         else:
# --> 687             raise AttributeError(attr + " not found")
#     688
#     689     def transpose(self, axes=None, copy=False):
#
# AttributeError: iloc not found

# %%
object_Columns
